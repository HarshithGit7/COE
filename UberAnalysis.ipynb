# %%
import pandas as pd

temp=pd.DataFrame(
{
    'A':[1,2],
    'B':[10,20],
    'C':['20-1-1925','20-1-2125']
    
})

temp.dtypes
# Out:
# A     int64
# B     int64
# C    object
# dtype: object

# %%
temp['C']=pd.to_datetime(temp['C'])
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp['A']=temp['A'].astype(bool)
temp.dtypes
# Out:
# A              bool
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
df = pd.read_csv(r'C:\Users\CVR\Desktop\6625\uber.csv')
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df[(df['MILES*']>6) & (df['MILES*']<8)]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 6       1/6/2016 17:30    1/6/2016 17:35  Business   West Palm Beach
# 11     1/10/2016 18:18   1/10/2016 18:53  Business          Elmhurst
# 12     1/10/2016 19:12   1/10/2016 19:32  Business           Midtown
# 13      1/11/2016 8:55    1/11/2016 9:21  Business       East Harlem
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# ...                ...               ...       ...               ...
# 1123  12/27/2016 16:34  12/27/2016 16:58  Business  Unknown Location
# 1138  12/29/2016 14:42  12/29/2016 14:58  Business           Kar?chi
# 1142  12/29/2016 20:15  12/29/2016 20:45  Business           Kar?chi
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
#
#                     STOP*  MILES*         PURPOSE*
# 6              Palm Beach     7.1          Meeting
# ...

# %%
c=df[(df['MILES*']>50) & (df['MILES*']<100)].iloc[:,3:6]
c
# Out:
#                START*             STOP*  MILES*
# 4         Fort Pierce   West Palm Beach    63.7
# 251         Galveston           Houston    57.0
# 295         Kissimmee     Daytona Beach    77.3
# 296     Daytona Beach      Jacksonville    80.5
# 707  Unknown Location  Unknown Location    96.2
# 710  Unknown Location  Unknown Location    50.4
# 726            Lahore  Unknown Location    86.6
# 751  Unknown Location  Unknown Location    69.1
# 871         Asheville            Topton    91.8
# 873        Hayesville            Topton    75.7
# 880       Bryson City         Asheville    68.4

# %%
e=df.loc[(df['MILES*']>50) & (df['MILES*']<100),['PURPOSE*','MILES*']]
e
# Out:
#            PURPOSE*  MILES*
# 4    Customer Visit    63.7
# 251  Customer Visit    57.0
# 295  Customer Visit    77.3
# 296  Customer Visit    80.5
# 707             NaN    96.2
# 710             NaN    50.4
# 726             NaN    86.6
# 751             NaN    69.1
# 871         Meeting    91.8
# 873             NaN    75.7
# 880             NaN    68.4

# %%
df.loc[df["START*"].isin(['New York','Cary'])]
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business      Cary           Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business      Cary    Morrisville
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 28     1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# ...                ...               ...       ...       ...            ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary           Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary           Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary           Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary    Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#       MILES*        PURPOSE*
# ...

# %%
new=df[df["START*"].isin(['New York','Cary']) & df["STOP*"].isin(['Queens','Morrisville']) & (df['MILES*']>6) & (df['MILES*']<8)]
new
# Out:
#           START_DATE*         END_DATE* CATEGORY* START*        STOP*  MILES*  \
# 81     2/7/2016 18:39    2/7/2016 18:53  Business   Cary  Morrisville     6.1
# 89     2/9/2016 18:55    2/9/2016 19:11  Business   Cary  Morrisville     6.1
# 193    3/5/2016 11:44    3/5/2016 11:59  Business   Cary  Morrisville     6.5
# 197    3/5/2016 16:52    3/5/2016 17:13  Business   Cary  Morrisville     7.8
# 302    4/7/2016 18:20    4/7/2016 18:39  Business   Cary  Morrisville     6.1
# 387   5/28/2016 12:52   5/28/2016 13:06  Business   Cary  Morrisville     6.1
# 392    6/1/2016 10:19    6/1/2016 10:47  Business   Cary  Morrisville     6.7
# 402    6/5/2016 15:06    6/5/2016 15:22  Business   Cary  Morrisville     7.8
# 493    6/29/2016 8:56    6/29/2016 9:24  Business   Cary  Morrisville     7.3
# 524     7/7/2016 8:22     7/7/2016 8:50  Business   Cary  Morrisville     7.9
# 586   7/22/2016 14:27   7/22/2016 14:43  Business   Cary  Morrisville     6.1
# ...

# %%
df['START_DATE*'] = pd.to_datetime(df['START_DATE*'], format="%m/%d/%Y %H:%M", errors='coerce')
df['END_DATE*'] = pd.to_datetime(df['END_DATE*'], format="%m/%d/%Y %H:%M", errors='coerce')
j = df[df['START_DATE*'].dt.year == 2016]
k = j[j['START_DATE*'].dt.month == 1]
k
# Out:
#            START_DATE*           END_DATE* CATEGORY*       START*  \
# 0  2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1  2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2  2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3  2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4  2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
# ..                 ...                 ...       ...          ...
# 56 2016-01-29 13:24:00 2016-01-29 13:47:00  Business       Durham
# 57 2016-01-29 18:31:00 2016-01-29 18:52:00  Business         Cary
# 58 2016-01-29 21:21:00 2016-01-29 21:40:00  Business         Apex
# 59 2016-01-30 16:21:00 2016-01-30 16:33:00  Business         Cary
# 60 2016-01-30 18:09:00 2016-01-30 18:24:00  Business         Apex
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# 1       Fort Pierce     5.0              NaN
# ...

# %%
import numpy as np

# %%
df.sort_values("MILES*")
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 420  2016-06-08 17:16:00 2016-06-08 17:18:00  Business              Soho
# 44   2016-01-26 17:27:00 2016-01-26 17:29:00  Business              Cary
# 120  2016-02-17 16:38:00 2016-02-17 16:43:00  Business        Katunayaka
# 1111 2016-12-25 00:10:00 2016-12-25 00:14:00  Business            Lahore
# 1110 2016-12-24 22:04:00 2016-12-24 22:09:00  Business            Lahore
# ...                  ...                 ...       ...               ...
# 776  2016-09-27 21:01:00 2016-09-28 02:37:00  Business  Unknown Location
# 881  2016-10-30 15:22:00 2016-10-30 18:23:00  Business         Asheville
# 270  2016-03-25 22:54:00 2016-03-26 01:39:00  Business      Jacksonville
# 269  2016-03-25 16:52:00 2016-03-25 22:22:00  Business             Latta
# 1155                 NaT                 NaT       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# ...

# %%
df.sort_values(by=["START*","MILES*"],ascending=(True,False))
# Out:
#              START_DATE*           END_DATE* CATEGORY*         START*  \
# 906  2016-11-04 21:04:00 2016-11-04 21:20:00  Business          Agnew
# 911  2016-11-06 10:50:00 2016-11-06 11:04:00  Business          Agnew
# 908  2016-11-05 08:34:00 2016-11-05 08:43:00  Business          Agnew
# 910  2016-11-05 19:20:00 2016-11-05 19:28:00  Business          Agnew
# 879  2016-10-30 12:58:00 2016-10-30 13:18:00  Business         Almond
# ...                  ...                 ...       ...            ...
# 889  2016-11-01 17:35:00 2016-11-01 17:42:00  Business    Whitebridge
# 890  2016-11-01 19:14:00 2016-11-01 19:20:00  Business    Whitebridge
# 516  2016-07-05 16:48:00 2016-07-05 16:52:00  Business    Whitebridge
# 870  2016-10-28 18:13:00 2016-10-28 20:07:00  Business  Winston Salem
# 1155                 NaT                 NaT       NaN            NaN
#
#             STOP*   MILES*         PURPOSE*
# 906          Cory      4.3              NaN
# ...

# %%
df["MILES_CAT"]=np.where(df['MILES*']>50,"Long trip","Short trip")
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   MILES_CAT
# ...

# %%
conditions=[(df["MILES*"]>100),(df["MILES*"]>50)&(df["MILES*"]<100),(df["MILES*"]>10)&(df["MILES*"]<50),(df["MILES*"]<10)]

constraints=["Long Trip","Medium Trip","Short Trip","Very Short Trip"]

df["MILES_CAT"]=np.select(conditions,constraints,default="unknown")

df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*        MILES_CAT
# ...

# %%
grp=df.groupby('CATEGORY*')['MILES*'].agg(['sum','mean','max'])
grp
# Out:
#                sum       mean    max
# CATEGORY*
# Business   11487.0  10.655844  310.3
# Personal     717.7   9.320779  180.2
