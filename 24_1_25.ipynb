# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshithGit7/COE/blob/main/24_1_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !cd

# %%
df=pd.read_csv(r"/content/movies.csv")
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
df.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994     True
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Length: 9999, dtype: bool

# %%
df.iloc[9994,:]
# Out:
# MOVIES                                         The Imperfects
# YEAR                                                 (2021– )
# GENRE                 \nAdventure, Drama, Fantasy
# RATING                                                    NaN
# ONE-LINE                                       \nAdd a Plot\n
# STARS       \n            \n    Stars:\nMorgan Taylor Camp...
# VOTES                                                     NaN
# RunTime                                                   NaN
# Gross                                                     NaN
# Name: 9994, dtype: object

# %%
df.drop_duplicates()
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9993                            Totenfrau     (2022– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df[x]=df[x].fillna(df[x].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4f43639dd453> in <cell line: 0>()
# ----> 1 df[x]=df[x].fillna(df[x].mean())
#       2
#
# NameError: name 'x' is not defined

# %%
df.isnull().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994     True
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Length: 9999, dtype: bool

# %%
#range of class column
print(fd["class"].min())
print(fd["class"].max())
# Out:
# 0
# 4

# %%
# !pip install plotly.express

# %%
import plotly.express as px

# %%
fd=pd.read_csv(r"/content/clevelanda (1).csv")
fd
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  class
# 0        3  0    6      0
# ...

# %%
px.histogram(fd,x="age",nbins=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fd["age"].hist()
# Out:
# <Axes: >

# %%
for i in fd.columns:
  print(f"{i}:{fd[i].unique()}")
# Out:
# age:[63 67 37 41 56 62 57 53 44 52 48 54 49 64 58 60 50 66 43 40 69 59 42 55
#  61 65 71 51 46 45 39 68 47 34 35 29 70 77 38 74 76]
# gender:[1 0]
# cp:[1 4 3 2]
# trestbps:[145 160 120 130 140 172 150 110 132 117 135 112 105 124 125 142 128 170
#  155 104 180 138 108 134 122 115 118 100 200  94 165 102 152 101 126 174
#  148 178 158 192 129 144 123 136 146 106 156 154 114 164]
# chol:[233 286 229 250 204 236 268 354 254 203 192 294 256 263 199 168 239 275
#  266 211 283 284 224 206 219 340 226 247 167 230 335 234 177 276 353 243
#  225 302 212 330 175 417 197 198 290 253 172 273 213 305 216 304 188 282
#  185 232 326 231 269 267 248 360 258 308 245 270 208 264 321 274 325 235
#  257 164 141 252 255 201 222 260 182 303 265 309 307 249 186 341 183 407
#  217 288 220 209 227 261 174 281 221 205 240 289 318 298 564 246 322 299
#  300 293 277 214 207 223 160 394 184 315 409 244 195 196 126 313 259 200
#  262 215 228 193 271 210 327 149 295 306 178 237 218 242 319 166 180 311
# ...

# %%
fd=fd.replace("?",np.NaN)
fd
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope   ca thal  class
# ...

# %%
fd["ca"]=fd["ca"].astype(float)

# %%
mean=fd["ca"].mean()
mean
# Out:
# 0.6722408026755853

# %%
mode=fd["ca"].mode()
mode
# Out:
# 0    0.0
# Name: ca, dtype: float64

# %%
median=fd["ca"].median()
median
# Out:
# 0.0

# %%
fd["thal"]=fd["thal"].astype(float)

# %%
fd["thal"].mean()
# Out:
# 4.73421926910299

# %%
fd["thal"].mode()
# Out:
# 0    3.0
# Name: thal, dtype: float64

# %%
fd["thal"].median()
# Out:
# 3.0

# %% [markdown]
# #mat plot lib
#
# matplot lob is an essential lib in python dta visualixationn land scape ..it serves as a powerful tool for creating  static ,animated and interactibe  visualizations in python
#
# key features:
#
# plot types : bar graphs.histogram,scale plot,pie chart...........
#
# customization :
#
# interacitivity :
#
# integration :
#
# #univariate analysis
#
# : analysis iof single variable to understand distribution ,central tendency, spread
# --histogram,bargraph,bar chart
#
# #bivariate analysis:
#
# : analysis of two to explore their relationship
# --scatter plot,line plot,heatmap.

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x=["January","February","March","April","May","June"]

y=[10000,11500,10800,12000,14000,15800]

plt.plot(x,y,color="blue",linestyle="--",linewidth=1,marker="*",markersize=5)

plt.xlabel("MONTHS ----->")
plt.ylabel("SAVINGS -------->")
# Out:
# Text(0, 0.5, 'SAVINGS -------->')

# %%
plt.bar(x,y,color="blue")
# Out:
# <BarContainer object of 6 artists>

# %%
slices=[3,5,7,8]
activities=['sleep','eating','wprking','playing']
cols=["c","m","r","b"]
